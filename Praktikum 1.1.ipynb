# %%
print('Nama              : Akmal Firdaus')
print("")
print('NPM               : 2420506020')
print("")
print('Alamat            : Potro Bangsan Rt01 Rw05, Magelang, Jawa Tengah')
print("")
print('Tinggi Bandan     : 162')
print("")
print('Berat Badan       : 59')
print("")
print("")

print('\033[1mUNIVERSITAS TIDAR\033[0m')
print('Uiniversitas TIdar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan oleh peraturan Presiden Republik Indonesia Nomer 23 Tahun 2014 pada tanggal 1 April 2014.')
print("")
print('\033[1mJURUSAN MEKATRONIKA, ELEKTRO, DAN INFORMASI\033[0m')
print('Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:')
print('   1. Teknik Elektro \x1B[3m(Bachelor of Electrical Engineering)\x1B[0m')
print('   2. Teknologi Informasi \x1B[3m(Bachelor of Information Technology)\x1B[0m')
print('   3. Teknik Mekatronika \x1B[3m(Bachelor of Mechatronics Engineering)\x1B[0m')
# Out:
# Nama              : Akmal Firdaus
#
# NPM               : 2420506020
#
# Alamat            : Potro Bangsan Rt01 Rw05, Magelang, Jawa Tengah
#
# Tinggi Bandan     : 162
#
# Berat Badan       : 59
#
#
# UNIVERSITAS TIDAR
# Uiniversitas TIdar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan oleh peraturan Presiden Republik Indonesia Nomer 23 Tahun 2014 pada tanggal 1 April 2014.
#
# JURUSAN MEKATRONIKA, ELEKTRO, DAN INFORMASI
# Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:
#    1. Teknik Elektro (Bachelor of Electrical Engineering)
#    2. Teknologi Informasi (Bachelor of Information Technology)
#    3. Teknik Mekatronika (Bachelor of Mechatronics Engineering)
