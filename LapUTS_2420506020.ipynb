# %%
num = int(input("MAsukkan Angka: "))

for i in range(1, num + 1):
    for j in range(1, i + 1):
        print(j * i, end=" ")
    print()
# Out:
# MAsukkan Angka: 6
# 1
# 2 4
# 3 6 9
# 4 8 12 16
# 5 10 15 20 25
# 6 12 18 24 30 36
