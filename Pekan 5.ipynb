# %%
tahun = int(input("MAsukkan Tahun:  "))
if (tahun % 4 == 0 and tahun % 100 != 0) or (tahun % 400 == 0):
    print(f"{tahun} Adalah tahun kabisat.")
else:
    print(f"{tahun} Adalah bukan tahun kabisat")
# Out:
# MAsukkan Tahun:  2000
# 2000 Adalah tahun kabisat.

# %%
angka1 = int(input("Masukkan angka pertama: "))
angka2 = int(input("Masukkan angka kedua: "))
angka3 = int(input("Masukkan angka ketiga: "))

if angka1 >= angka2 and angka1 >= angka3:
    terbesar = angka1
elif angka2 >= angka1 and angka2 >= angka3:
    terbesar = angka2
else:
    terbesar = angka3

print(f"Angka pertama: {angka1}")
print(f"Angka kedua: {angka2}")
print(f"Angka ketiga: {angka3}")
print(f"Angka terbesarnya adalah: {terbesar}")
# Out:
# Masukkan angka pertama: 300
# Masukkan angka kedua: 20
# Masukkan angka ketiga: 90
# Angka pertama: 300
# Angka kedua: 20
# Angka ketiga: 90
# Angka terbesarnya adalah: 300

# %%
jenis_konsumen = input("Apakah Anda Member? (ya/tidak): ")
total_belanja = float(input("Masukkan total belanja: "))

if total_belanja > 200000:
    diskon = 0.04
elif total_belanja > 100000:
    diskon = 0.03
else:
    diskon = 0.0

if jenis_konsumen == "ya":
    diskon += 0.02

jumlah_diskon = total_belanja * diskon
jumlah_bayar = total_belanja - jumlah_diskon

print(f"Total Belanja: Rp{total_belanja:.2f}")
print(f"Diskon: Rp{jumlah_diskon:.2f}")
print(f"Total Harga: Rp{jumlah_bayar:.2f}")
# Out:
# Apakah Anda Member? (ya/tidak): ya
# Masukkan total belanja: 90000
# Total Belanja: Rp90000.00
# Diskon: Rp1800.00
# Total Harga: Rp88200.00

# %%
print("New user")

username = input("Masukkan username: ")
email = input("Masukkan email: ")
password = input("Masukkan password (minimal 8 karakter): ")

if username == "":
    print("Username tidak boleh kosong.\n")
elif "@" not in email:
    print("Alamat email tidak valid.\n")
elif len(password) < 8:
    print("Password terlalu pendek. Minimal 8 karakter.\n")
else:
    print("User baru berhasil dibuat")
    print(f"username: {username}")
    print(f"Email: {email}")
# Out:
# New user
# Masukkan username: skibidi
# Masukkan email: @skibidimaksimal
# Masukkan password (minimal 8 karakter): hariyangindah
# User baru berhasil dibuat
# username: skibidi
# Email: @skibidimaksimal
