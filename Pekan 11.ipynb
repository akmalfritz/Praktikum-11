# %%
from matematika import luas_lingkaran, luas_persegi

print(PI)
print(luas_lingkaran(PI,6))
print(luas_persegi(5))
# Out:
# 3.14
# 113.03999999999999
# 25

# %%
from math import pi,sqrt,ceil,floor,sin,cos,tan

print("Niali pi: ",pi)
print("Nilai akar kuadrat: ",sqrt(9))
print("Niali angka bulat ke atas: ",ceil(7.8))
print("Nilai angka bulat ke bawah: ",floor(7.2))
print("Nilai sin: ",sin(30))
print("Nilai cos: ",cos(30))
print("Nilai tan: ",tan(30))
# Out:
# Niali pi:  3.141592653589793
# Nilai akar kuadrat:  3.0
# Niali angka bulat ke atas:  8
# Nilai angka bulat ke bawah:  7
# Nilai sin:  -0.9880316240928618
# Nilai cos:  0.15425144988758405
# Nilai tan:  -6.405331196646276
